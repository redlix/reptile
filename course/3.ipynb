# %%
import urllib.request
import re

cid="6375489932584768380"
for i in range(0,100):
    print("第"+str(i+1)+"页的评论数据")
    url="https://video.coral.qq.com/varticle/2461939412/comment/v2?callback=_varticle2461939412commentv2&orinum=10&oriorder=o&pageflag=1&cursor="+str(cid)+"&scorecursor=0&orirepnum=2&reporder=o&reppageflag=1&source=9"
    data=urllib.request.urlopen(url).read().decode("utf-8","ignore")
    pat1='"content":"(.*?)"'
    comment=re.compile(pat1,re.S).findall(data)
    for item in comment:
        print(eval('u"'+str(item)+'"'))
        print("-------")
    pat2='"last":"(.*?)"'
    cid=re.compile(pat2,re.S).findall(data)[0]
# Out:
# 第1页的评论数据
# dyifududidtyi8dudtxukggixuitiddiiykkhdcjgmyjuccggiyygdcykkggdgiiijjisistuugsix,kvxjvjgkhdutxgusgukhfuof
# -------
# 大家不要因为前面看不懂就放弃追剧，小说很好看，韩东君演出了易连凯，孙怡虽然造型不好看，但是演得还是很不错。前面的迷雾会随着解开的，易连凯是少有的只爱美人不爱江山的人，整部剧都很虐易三，秦桑家败，任用潘健迟都是为了娶到秦桑，得到秦桑的心，到大结局他都带着遗憾死去，秦桑到最后都没告诉易连凯她爱他，不过不知道小说改变大不大。真的觉得这部剧拍得不错。
# -------
# 这电视有点莫名其妙，前景也不介绍清楚，这对夫妻怎么结合的，有点奇怪！起码前面介绍一下呀！
# -------
# 我觉得挺好看的，男女主演演技都在线，虽然背景设定目前有些混乱，但是多看几集自然就理清楚了，而男女主角之前发生的事情，也会通过插叙的播放手法来展现
# -------
# 名字很喜欢 人生若只如初见 然而初见总是瞬间 人生却长久 没有一直的若只如初见 只有不停变化的心
# -------
# 这部剧好多“孤独天下”里面的演员，“因为遇见你”喜欢上果果，“无心法师”喜欢上男主，里面好多演员都挺喜欢的，虽然明知道是悲剧还是来看了…
# -------
# 现在还没空看，等大结局了，再看，看最后一集，男主死的话就弃剧，不死的话，就从头再看
# -------
# 我是看明白了，只要是民国剧，中后期一定会有日军攻占城池，然后男女主历经劫难幸福的在一起，那就让男女主幸福，快乐的在一起吧！
# -------
# 这部电视剧真的非常虐，我看了很多预告小视频，虐到我哭，秦桑啊，易连凯对你那么好，那么爱你，只不过是太霸道了。你为什么要一直心系男二呢。真的很虐，真的很虐，真的很虐。真的真的的
# -------
# 果断弃剧，不如小说有意思。女主表面太强势了，没有原著里的外柔内刚，而且还把潘健迟改成了潘箭迟，加多了慕容沣的剧情，不过慕容沣还是挺帅的。第一集范知衡
# -------
# 他八成是在网吧抢小学生电脑被小学生给按在键盘上了
# -------
# 翻译
# -------
# 孙怡这造型还不好看？你要人家怎样啊
# -------
# 孙怡挺好看的呀
# -------
# 同感
# -------
# 对呀……有点看不懂
# -------
# 主要是男女主在小鲜肉之中，演技还是很好的，从韩东君演无心法师，从孙怡的因为遇见你，这两个我还是很喜欢的
# -------
# 我也觉得很好看
# -------
# 哇 看到徐正溪了 最近被太师迷得不要不要的
# -------
# 是......是........是悲剧吗？那窝窝窝就不想看了
# -------
# 男主有光环不会死
# -------
# 不死就不能用人：生若如初相见了
# -------
# 韩东君几乎没玩过美满的结局
# -------
# 这部戏是悲剧，好吗？
# -------
# 其实女主已经喜欢男主了吧，只是女主觉得男主不喜欢她，只是都不把心里的话说出来罢了
# -------
# 其实她也爱着易连恺，只是她没有意识到。
# -------
# 来不及说我爱你，那个剧慕容沣才帅，钟汉良演的
# -------
# 其实全部和小说一样就没有意思了
# -------
# 第3页的评论数据
# 过来看太帅的，看独孤天下过来的点赞
# -------
# 好喜欢秦桑，演技很到位
# -------
# 死女人，臭女人，真的很讨厌女主角
# -------
# 对，其实，易连恺对秦桑爱的深沉，也爱的卑微，秦桑一句“我在你身边感受的全是痛苦”，就让易连恺放手让秦桑走。在秦桑拉下衣服拉链的时候，易连恺还问秦桑是真的接受自己了吗？这样卑微的爱，注定是要为对方粉身碎骨的。
# -------
# 第一次看这种电视剧，还是觉得还好看嘛，三少那个女的，怎么那么狡猾呢？大家告诉我呢？
# -------
# 易连恺对秦桑爱的深沉，也爱的卑微，秦桑一句“我在你身边感受的全是痛苦”，就让易连恺放手让秦桑走。在秦桑拉下衣服拉链的时候，易连恺还问秦桑是真的接受自己了吗？这样卑微的爱，注定是要为对方粉身碎骨的。
# -------
# 好讨厌秦桑，好讨厌，好讨厌，好讨厌……
# -------
# 垃圾女主 神经病 他妈屁
# -------
# 没有什么好结局，不爽
# -------
# 自私的父亲，江山也不是的。
# -------
# 第7页的评论数据
# 第一次评论弃剧，女主太恶心了
# -------
# 女主真的好丑，太瘦了穿的衣服不好看，我是为了男主才把它看完的
# -------
# 这结局简直了……，为什么男主会死，而不是和女主一起
# -------
# 那个女一没气质……ci
# -------
# 谁能了解三少内心的孤独……
# -------
# 秦桑哭起来好丑好老！
# -------
# 易连凯永远都记得他和秦桑的第一次见面，而秦桑永远都记得易连凯那句话，我叫易连凯，其实他们很相爱，只是秦桑明白得太晚了，来不及了，秦桑活着其实在完成易连凯的遗愿，因为易连凯希望她活着，所以啊在这乱世之中秦桑只能等着和易连凯相聚的那一天
# -------
# 广告太了少点巴？？？？
# -------
# 看不懂女主怎么那么傻白啊，被人挑拨挑拨就找不着东南西北了
# -------
# 女主又贱又眼瞎，装什么装，感觉不到男主爱她吗
# -------
# 第8页的评论数据
# 我现在终于明白了,只要凑到十五字,就可以升级,以前我还不知道.就是为了升级!凑热闹而已！！这是真的吗？我就是试试！！
# -------
# 好看更新太慢了，看都没兴趣了。
# -------
# 杀师父的人是潘建迟吧
# -------
# 太讨厌女主了，看着特想打人
# -------
# 秦桑到底喜欢三少还是喜欢潘劍迟
# -------
# 讨厌秦双，都不想看了
# -------
# 感觉不到一点点正能量
# -------
# 这个三少奶奶那里找的。真是一大败笔。三少爷这么聪明怎么配了这么一个笨女r
# -------
# 假如不是这么多明星的电视剧，真不想看，一个字，撇
# -------
# 本剧最大的败笔：影片结尾孩子没出现
# -------
# 第14页的评论数据
# 女主无论长相和性格都和原著差得太多！
# -------
# 女二比女主好看，又是一个女主被忽视的剧
# -------
# 为什么秦桑死活不愿意跟易连恺啊
# -------
# 女主实在喜欢不起来，没依据就在那里当搅屎棍胡搅
# -------
# 人生若只如初见，何事秋风悲画扇。等闲变却故人心，却道故人心易变。骊山语罢清宵半，泪雨霖铃终不怨。何如薄幸锦衣郎，比翼连枝当日愿！
# -------
# 好看好看好看真好看好看好看特好看
# -------
# 看得我心好疼，你们两个为什么要这样对待对方啊
# -------
# 开局90秒广告、中间45秒、
# -------
# 肌肉，哇哦
# -------
# 秦桑回来的时候不是她丫鬟跟着吗？怎么秦桑爹着急的时候，不告诉秦桑回来了
# -------
# 第17页的评论数据
# 易连凯最后死了吗，看到中枪了
# -------
# 好奇怪孙怡是怎么红的 演技我就不說了 感覺她整個人土土的
# -------
# 越来越不喜欢秦桑，真的越看越有气
# -------
# 无语！三少这么明确说不爱，只当妹妹。燕云还认为三少是骗她才那样说的，是爱她的！
# -------
# 不知道为什么我越来越讨厌秦桑了（不是说讨厌这个演员，只是讨厌这个角色）
# -------
# 易连凯永远都记得他和秦桑的第一次见面，而秦桑永远都记得易连凯那句话，我叫易连凯，其实他们很相爱，只是秦桑明白得太晚了，来不及了，秦桑活着其实在完成易连凯的遗愿，因为易连凯希望她活着，所以啊在这乱世之中秦桑只能等着和易连凯相聚的那一天
# -------
# 家业不能太大，辛辛苦苦一辈子，照样会被败光。
# -------
# 越做越乱不知道做什么鬼
# -------
# 好看好看特别好看，非常棒
# -------
# 这女主的嘴看着跟兔子嘴似的
# -------
# 第22页的评论数据
# 真不知道秦桑还有什么委屈呵呵
# -------
# 这部电视剧不是有颜值撑着真没看头
# -------
# 第23页的评论数据
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-bcbeec33486c> in <module>()
#      13         print("-------")
#      14     pat2='"last":"(.*?)"'
# ---> 15     cid=re.compile(pat2,re.S).findall(data)[0]
#
# IndexError: list index out of range
